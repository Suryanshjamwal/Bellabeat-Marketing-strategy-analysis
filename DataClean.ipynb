# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading Datasets

# %% [markdown]
# ## Daily Activity Dataset

# %%
dfAct = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')
dfAct
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
list(dfAct.columns.values)
# Out:
# ['Id',
#  'ActivityDate',
#  'TotalSteps',
#  'TotalDistance',
#  'TrackerDistance',
#  'LoggedActivitiesDistance',
#  'VeryActiveDistance',
#  'ModeratelyActiveDistance',
#  'LightActiveDistance',
#  'SedentaryActiveDistance',
#  'VeryActiveMinutes',
#  'FairlyActiveMinutes',
#  'LightlyActiveMinutes',
#  'SedentaryMinutes',
#  'Calories']

# %%
dfAct.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %% [markdown]
# ### Key Takeaways:
#
#     * Average(Mean) Sedentry minutes is 991.2 minutes or 16.5 hours/day! That's almost close to 70% of a day.
#
#     * Most users are lightly active users.
#
#     * Average total steps per day is 7637. Recommended total steps is 10,000 according to CDC.

# %% [markdown]
# ## Daily Calories Dataset

# %%
dfCal = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv')
dfCal
# Out:
#              Id ActivityDay  Calories
# 0    1503960366   4/12/2016      1985
# 1    1503960366   4/13/2016      1797
# 2    1503960366   4/14/2016      1776
# 3    1503960366   4/15/2016      1745
# 4    1503960366   4/16/2016      1863
# ..          ...         ...       ...
# 935  8877689391    5/8/2016      2847
# 936  8877689391    5/9/2016      3710
# 937  8877689391   5/10/2016      2832
# 938  8877689391   5/11/2016      3832
# 939  8877689391   5/12/2016      1849
#
# [940 rows x 3 columns]

# %%
dfCal.describe()
# Out:
#                  Id     Calories
# count  9.400000e+02   940.000000
# mean   4.855407e+09  2303.609574
# std    2.424805e+09   718.166862
# min    1.503960e+09     0.000000
# 25%    2.320127e+09  1828.500000
# 50%    4.445115e+09  2134.000000
# 75%    6.962181e+09  2793.250000
# max    8.877689e+09  4900.000000

# %% [markdown]
# ## Daily Intensity Dataset

# %%
dfInt = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv')
dfInt
# Out:
#              Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0    1503960366   4/12/2016               728                   328
# 1    1503960366   4/13/2016               776                   217
# 2    1503960366   4/14/2016              1218                   181
# 3    1503960366   4/15/2016               726                   209
# 4    1503960366   4/16/2016               773                   221
# ..          ...         ...               ...                   ...
# 935  8877689391    5/8/2016              1174                   245
# 936  8877689391    5/9/2016              1131                   217
# 937  8877689391   5/10/2016              1187                   224
# 938  8877689391   5/11/2016              1127                   213
# 939  8877689391   5/12/2016               770                   137
#
#      FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                     13                 25                     0.00
# ...

# %%
dfInt.describe()
# Out:
#                  Id  SedentaryMinutes  LightlyActiveMinutes  \
# count  9.400000e+02        940.000000            940.000000
# mean   4.855407e+09        991.210638            192.812766
# std    2.424805e+09        301.267437            109.174700
# min    1.503960e+09          0.000000              0.000000
# 25%    2.320127e+09        729.750000            127.000000
# 50%    4.445115e+09       1057.500000            199.000000
# 75%    6.962181e+09       1229.500000            264.000000
# max    8.877689e+09       1440.000000            518.000000
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# count           940.000000         940.000000               940.000000
# mean             13.564894          21.164894                 0.001606
# std              19.987404          32.844803                 0.007346
# min               0.000000           0.000000                 0.000000
# ...

# %% [markdown]
# ## Daily Steps Dataset

# %%
dfStep = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/dailysteps_merged.csv')
dfStep.head()
# Out:
#            Id ActivityDay  StepTotal
# 0  1503960366   4/12/2016      13162
# 1  1503960366   4/13/2016      10735
# 2  1503960366   4/14/2016      10460
# 3  1503960366   4/15/2016       9762
# 4  1503960366   4/16/2016      12669

# %%
dfStep.describe()
# Out:
#                  Id     StepTotal
# count  9.400000e+02    940.000000
# mean   4.855407e+09   7637.910638
# std    2.424805e+09   5087.150742
# min    1.503960e+09      0.000000
# 25%    2.320127e+09   3789.750000
# 50%    4.445115e+09   7405.500000
# 75%    6.962181e+09  10727.000000
# max    8.877689e+09  36019.000000

# %% [markdown]
# ## Daily Sleep Dataset

# %%
dfSleep = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv')
dfSleep
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %% [markdown]
# ## Weight Log Dataset

# %%
dfw = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv')
dfw
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %% [markdown]
# ## Hourly Steps Dataset

# %%
dfHStep = pd.read_csv('/Users/suryanshjamwal/Desktop/Analytics Case studies/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv')
dfHStep.head()
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0

# %% [markdown]
# #### Seems like the datasets have common attributes and values.
# #### We only use 'dailyActivity_merged' as the main dataframe as 'dailyCalories_merged',
# #### 'dailyIntensities_merged' and 'dailysteps_merged' are all subsets of it.
# #### We verified that in the sql file.

# %% [markdown]
# # Data cleaning and transformation

# %% [markdown]
# ## Checking for number of distinct values

# %%
dfAct['Id'].nunique()
# Out:
# 33

# %%
dfSleep['Id'].nunique()
# Out:
# 24

# %%
dfw['Id'].nunique()
# Out:
# 8

# %%
dfHStep['Id'].nunique()
# Out:
# 33

# %% [markdown]
# #### The weight info database is limited to 8 unique ID's. It would hinder with providing any concrete conclusions.
# #### Hence, it must be excluded from the analyis.

# %% [markdown]
# ## Checking for duplicates

# %%
len(dfAct)-len(dfAct.drop_duplicates())
# Out:
# 0

# %%
len(dfSleep)-len(dfSleep.drop_duplicates())
# Out:
# 3

# %%
len(dfHStep)-len(dfHStep.drop_duplicates())
# Out:
# 0

# %%
# dropping duplicates in Sleep dataset

dfS = dfSleep.drop_duplicates()
len(dfS)-len(dfS.drop_duplicates())

# dfS is the updated Sleep dataset
# Out:
# 0

# %% [markdown]
# ## Converting timestamps

# %%
dfAct['ActivityDate'] = pd.to_datetime(dfAct['ActivityDate'], format='%m/%d/%Y')
dfAct['day_of_week'] = dfAct['ActivityDate'].dt.day_name()

# %%
dfAct
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
dfS[['Date', 'Time']] = dfS['SleepDay'].str.split(' ', 1, expand=True)
# Out:
# /var/folders/sv/hr00cdg153nd74z0xfz926y40000gn/T/ipykernel_41852/1015236849.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   dfS[['Date', 'Time']] = dfS['SleepDay'].str.split(' ', 1, expand=True)
# /var/folders/sv/hr00cdg153nd74z0xfz926y40000gn/T/ipykernel_41852/1015236849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfS[['Date', 'Time']] = dfS['SleepDay'].str.split(' ', 1, expand=True)
# /var/folders/sv/hr00cdg153nd74z0xfz926y40000gn/T/ipykernel_41852/1015236849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfS['Date'] = pd.to_datetime(dfS['Date'], format='%m/%d/%Y')
dfS['day_of_week'] = dfS['Date'].dt.day_name()
# Out:
# /var/folders/sv/hr00cdg153nd74z0xfz926y40000gn/T/ipykernel_41852/1353775894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfS['Date'] = pd.to_datetime(dfS['Date'], format='%m/%d/%Y')
# /var/folders/sv/hr00cdg153nd74z0xfz926y40000gn/T/ipykernel_41852/1353775894.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfS['day_of_week'] = dfS['Date'].dt.day_name()

# %%
dfHStep[['Date', 'Time', 'AM/PM']] = dfHStep['ActivityHour'].str.split(' ', 2, expand=True)
# Out:
# /var/folders/sv/hr00cdg153nd74z0xfz926y40000gn/T/ipykernel_41852/3653198968.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   dfHStep[['Date', 'Time', 'AM/PM']] = dfHStep['ActivityHour'].str.split(' ', 2, expand=True)

# %%
dfHStep['Hour'] = dfHStep['Time'] + " " + dfHStep['AM/PM']
dfHStep
# Out:
#                Id           ActivityHour  StepTotal       Date      Time  \
# 0      1503960366  4/12/2016 12:00:00 AM        373  4/12/2016  12:00:00
# 1      1503960366   4/12/2016 1:00:00 AM        160  4/12/2016   1:00:00
# 2      1503960366   4/12/2016 2:00:00 AM        151  4/12/2016   2:00:00
# 3      1503960366   4/12/2016 3:00:00 AM          0  4/12/2016   3:00:00
# 4      1503960366   4/12/2016 4:00:00 AM          0  4/12/2016   4:00:00
# ...           ...                    ...        ...        ...       ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514  5/12/2016  10:00:00
# 22095  8877689391  5/12/2016 11:00:00 AM       1407  5/12/2016  11:00:00
# 22096  8877689391  5/12/2016 12:00:00 PM       3135  5/12/2016  12:00:00
# 22097  8877689391   5/12/2016 1:00:00 PM        307  5/12/2016   1:00:00
# 22098  8877689391   5/12/2016 2:00:00 PM        457  5/12/2016   2:00:00
#
#       AM/PM         Hour
# 0        AM  12:00:00 AM
# 1        AM   1:00:00 AM
# ...

# %%
dfHStep['Date'] = pd.to_datetime(dfHStep['Date'], format='%m/%d/%Y')
dfHStep['day_of_week'] = dfHStep['Date'].dt.day_name()

# %% [markdown]
# ## Data Merging

# %%
dfActS = pd.merge(dfAct, dfS,  how='left', left_on=['Id','ActivityDate'], right_on = ['Id','Date'])

# %%
dfActS
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
dfActS.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %% [markdown]
# ### Key Takeaways:
#     * Average sleep hours is 7 Hours.

# %% [markdown]
# ## Exporting the dataframes for visualisations

# %%
dfActS.to_csv('DailyActivitySleep.csv', index=False)

# %%
dfS.to_csv('DailySleep.csv', index=False)

# %%
dfHStep.to_csv('HourlyStep.csv', index=False)
